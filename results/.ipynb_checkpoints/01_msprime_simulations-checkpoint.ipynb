# %%
import msprime
import numpy as np
import sys
from IPython.display import SVG
# %load_ext rpy2.ipython
# %reload_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
#
# library(tidyverse)

# %%
# %%R
#
# tab <- tibble()
# for (sim in 1:20) {
#     for (rho in c('0.0001', '0.0005', '0.001', '0.005', '0.01', '0.05', '0.1', '0.5')) {
#         for (tht in c('0.0001', '0.0005', '0.001', '0.005', '0.01', '0.05', '0.1', '0.5')) {
#             tab <- read_csv(paste0('../steps/01_msprime_simulations/sim', sim, '_rho', rho, '_tht', tht, '.csv'),
#                            show_col_types = FALSE) %>%
#                 mutate(
#                     sim = sim,
#                     rho = rho,
#                     tht = tht
#                 ) %>%
#                 bind_rows(tab)
#         }
#     }
# }

# %%
# %%R -w 800
#
# tab %>%
#     group_by(sim, rho, tht) %>%
#     filter(step == which.max(step)) %>%
#     ungroup() %>%
#     ggplot() +
#     geom_hline(aes(yintercept = 1)) +
#     # geom_hline(aes(yintercept = y), data = tibble(y=c(0.5, 2))) +
#     geom_hline(aes(yintercept = y), linetype = 2, data = tibble(y=c(0.1, 10))) +
#     geom_boxplot(aes(
#         rho,
#         par1/as.numeric(rho),
#         color = rho),
#         outlier.shape = NA) +
#     geom_point(aes(
#         rho,
#         par1/as.numeric(rho),
#         color = rho),
#         alpha = 0.3) +
#     geom_point(aes(x, y), shape = 3,
#                data =
#                tibble(
#                    x = c('0.0001', '0.0005', '0.001', '0.005', '0.01', '0.05', '0.1', '0.5'),
#                    y = 0.000001/as.numeric(x))) +
#     geom_point(aes(x, y), shape = 3,
#                data =
#                tibble(
#                    x = c('0.0001', '0.0005', '0.001', '0.005', '0.01', '0.05', '0.1', '0.5'),
#                    y = 10/as.numeric(x))) +
#     facet_wrap(~tht, scales = 'free_x', labeller = label_both) +
#     scale_y_log10() +
#     annotation_logticks(sides = 'l') +
#     theme_minimal() +
#     ylab('Estimated rho / real rho') +
#     xlab('Real rho')

# %% [markdown]
# The above plots show the estimated rho relative to the real rho used in the simulations for different values of theta. The continuous horizontal line intersects at 1, and dashed lines represent a 10-fold increase or decrease in the relative rho. Crosses represent the upper and lower limits of the optimization.

# %% [markdown]
# We can see that, when theta is small, rho is greately underestimated, and it appears to be snapped to the minimum value. This might be because there are not enough mutations to fir the model correctly. In more intermediate theta values (0.001-0.01), the rho values are estimated correctly.

# %%
# %%R -w 800
#
# tab %>%
#     group_by(sim, rho, tht) %>%
#     filter(step == which.max(step)) %>%
#     ungroup() %>%
#     ggplot() +
#     geom_hline(aes(yintercept = 1)) +
#     geom_hline(aes(yintercept = y), linetype = 2, data = tibble(y=c(0.1, 10))) +
#     geom_boxplot(aes(tht,
#                    par2/as.numeric(tht),
#                    color = tht),
#                  outlier.shape = NA) +
#     geom_point(aes(tht,
#                    par2/as.numeric(tht),
#                    color = tht),
#         alpha = 0.3) +
#     geom_point(aes(x, y), shape = 3,
#                data =
#                tibble(
#                    x = c('0.0001', '0.0005', '0.001', '0.005', '0.01', '0.05', '0.1', '0.5'),
#                    y = 0.000001/as.numeric(x))) +
#     geom_point(aes(x, y), shape = 3,
#                data =
#                tibble(
#                    x = c('0.0001', '0.0005', '0.001', '0.005', '0.01', '0.05', '0.1', '0.5'),
#                    y = 10/as.numeric(x))) +
#     facet_wrap(~rho, scales = 'free_x', labeller = label_both) +
#     scale_y_log10() +
#     annotation_logticks(sides = 'l') +
#     theme_minimal()+
#     ylab('Estimated theta / real theta') +
#     xlab('Real theta')

# %% [markdown]
# The above plots show the estimated theta relative to the real theta used in the simulations for different values of rho. The continuous horizontal line intersects at 1, and dashed lines represent a 10-fold increase or decrease in the relative theta. Crosses represent the upper and lower limits of the optimization.

# %% [markdown]
# Theta is generally well estimated for low to intermediate values (0.0001-0.01). For small values of

# %%
# %%R
#
# tab %>%
#     group_by(sim, rho, tht) %>%
#     filter(step == which.max(step))
# Out:
# # A tibble: 1,280 × 9
# # Groups:   sim, rho, tht [1,280]
#     step    par1      par2      fn         gr1         gr2   sim rho   tht
#    <dbl>   <dbl>     <dbl>   <dbl>       <dbl>       <dbl> <int> <chr> <chr>
#  1    22 0.428   0.492     57644.     0.000207    0.00159     20 0.5   0.5
#  2    16 0.00726 1         30531.     0.00694  -221.          20 0.5   0.1
#  3    20 0.00001 0.643     19537.  7154.         -0.000165    20 0.5   0.05
#  4    11 0.220   0.00986    5463.    -0.00103     0.152       20 0.5   0.01
#  5    30 0.337   0.00481    3032.    -0.0169      0.332       20 0.5   0.005
#  6    38 0.120   0.000964    761.    -0.171       8.51        20 0.5   0.001
#  7    17 0.00001 0.0149      343.  2076.          0.000112    20 0.5   0.0005
#  8    52 0.00001 0.0000210    73.2 9208.       4342.          20 0.5   0.0001
#  9    21 0.0915  0.499     55227.    -0.0224      0.00169     20 0.1   0.5
# 10    35 0.0764  0.0996    28142.    -0.00534    -0.0401      20 0.1   0.1
# # … with 1,270 more rows

# %%
# %%R
#
# tab %>%
#     group_by(sim, rho, tht) %>%
#     filter(step == which.max(step), rho == 0.5) %>%
#     select(sim, step, par1, rho, par2, tht, everything()) %>%
#     print(n = 1)
# Out:
# # A tibble: 160 × 9
# # Groups:   sim, rho, tht [160]
#       sim  step      par1 rho        par2 tht         fn      gr1      gr2
#     <int> <dbl>     <dbl> <chr>     <dbl> <chr>    <dbl>    <dbl>    <dbl>
#   1    20    22 0.428     0.5   0.492     0.5    57644.   2.07e-4  1.59e-3
#   2    20    16 0.00726   0.5   1         0.1    30531.   6.94e-3 -2.21e+2
#   3    20    20 0.00001   0.5   0.643     0.05   19537.   7.15e+3 -1.65e-4
#   4    20    11 0.220     0.5   0.00986   0.01    5463.  -1.03e-3  1.52e-1
#   5    20    30 0.337     0.5   0.00481   0.005   3032.  -1.69e-2  3.32e-1
#   6    20    38 0.120     0.5   0.000964  0.001    761.  -1.71e-1  8.51e+0
#   7    20    17 0.00001   0.5   0.0149    0.0005   343.   2.08e+3  1.12e-4
#   8    20    52 0.00001   0.5   0.0000210 0.0001    73.2  9.21e+3  4.34e+3
#   9    19    22 0.461     0.5   0.503     0.5    59432.  -3.72e-4 -4.21e-3
#  10    19    23 0.00508   0.5   1         0.1    30936.  -3.01e-1 -4.95e+2
#  11    19    30 0.000969  0.5   0.631     0.05   19069.  -4.45e+0 -1.82e-1
#  12    19    17 0.583     0.5   0.00993   0.01    5510.  -1.10e-3 -1.25e-1
#  13    19    21 1         0.5   0.00505   0.005   3163.  -8.73e-1 -6.73e-1
#  14    19    38 0.972     0.5   0.000983  0.001    775.  -2.12e-1 -1.39e+2
#  15    19    42 0.00001   0.5   0.000334  0.0005   430.   2.21e+4 -3.50e+2
#  16    19    61 0.00001   0.5   0.0000491 0.0001   119.   8.16e+3  5.84e+3
#  17    18    21 0.477     0.5   0.500     0.5    59977.   1.01e-3 -4.35e-2
#  18    18    15 0.00586   0.5   1         0.1    30810.  -1.38e-1 -3.83e+2
#  19    18    28 0.00001   0.5   0.618     0.05   18984.   4.04e+3 -1.33e-5
#  20    18    16 0.616     0.5   0.0106    0.01    5797.  -5.80e-3 -1.35e+0
#  21    18    23 1         0.5   0.00519   0.005   3237.  -8.75e-1 -2.34e+0
#  22    18    32 0.456     0.5   0.00105   0.001    823.  -2.09e-1 -3.08e+1
#  23    18    15 0.00001   0.5   0.00602   0.0005   412.   6.79e+3 -8.77e-3
#  24    18    57 0.00001   0.5   0.000119  0.0001   101.   2.79e+3 -7.84e+2
#  25    17    22 0.472     0.5   0.511     0.5    58672.  -6.85e-4  3.90e-3
#  26    17    15 0.00470   0.5   1         0.1    30666.  -1.23e-2 -3.31e+2
#  27    17    55 0.382     0.5   0.0484    0.05   18436.  -1.49e-5  8.04e-4
#  28    17    15 0.361     0.5   0.0103    0.01    5683.  -4.27e-6  1.65e-4
#  29    17    25 1         0.5   0.00512   0.005   3193.  -1.79e-2 -3.06e-3
#  30    17    40 0.707     0.5   0.00114   0.001    885.  -8.09e-2 -2.87e+1
#  31    17    60 0.00001   0.5   0.000285  0.0005   368.   2.14e+4 -2.72e+2
#  32    17    62 0.00001   0.5   0.0000613 0.0001   110.   3.87e+2  6.24e+3
#  33    16    22 0.463     0.5   0.493     0.5    58283.   3.64e-4 -2.88e-2
#  34    16    15 0.00741   0.5   1         0.1    30776.  -4.47e-4 -2.68e+2
#  35    16    35 0.000290  0.5   0.648     0.05   19561.  -8.85e+1  7.62e-2
#  36    16    13 0.360     0.5   0.00946   0.01    5290.  -2.88e-3 -9.30e-1
#  37    16    19 0.262     0.5   0.00489   0.005   3070.  -1.61e-4  1.91e-3
#  38    16    31 0.0951    0.5   0.000923  0.001    732.  -2.60e-2 -1.80e+0
#  39    16    26 0.00001   0.5   0.000387  0.0005   505.   1.66e+4 -9.50e+1
#  40    16    33 0.00001   0.5   0.0000490 0.0001    91.8  4.30e+3  8.78e+3
#  41    15    22 0.483     0.5   0.495     0.5    58497.  -5.31e-2  7.00e-2
#  42    15    15 0.00619   0.5   1         0.1    30559.  -4.67e-2 -4.34e+2
#  43    15    11 0.0000100 0.5   0.591     0.05   19359.   6.92e+3  0
#  44    15    14 0.539     0.5   0.0103    0.01    5680.  -3.71e-4  1.36e+0
#  45    15    24 0.435     0.5   0.00502   0.005   3145.   5.84e-4 -1.25e+1
#  46    15    20 0.0552    0.5   0.000986  0.001    773.  -1.27e-4  2.40e-3
#  47    15    28 0.00001   0.5   0.00666   0.0005   450.   6.75e+3 -2.16e-2
#  48    15    47 0.00001   0.5   0.0000225 0.0001    83.0  1.35e+4  2.05e+3
#  49    14    20 0.415     0.5   0.494     0.5    59485.  -6.08e-3  3.96e-3
#  50    14    14 0.00723   0.5   1         0.1    30703.   3.48e-2 -2.85e+2
#  51    14    11 0.0000100 0.5   0.698     0.05   19387.   6.48e+3  0
#  52    14    23 0.315     0.5   0.0101    0.01    5585.  -3.95e-3 -3.25e-1
#  53    14    19 0.209     0.5   0.00477   0.005   3012.  -1.17e-5 -2.59e-3
#  54    14    35 1         0.5   0.00103   0.001    810.  -2.76e-1 -5.63e+0
#  55    14    55 0.00001   0.5   0.000381  0.0005   512.   9.44e+3 -7.11e+0
#  56    14    59 0.00001   0.5   0.0000489 0.0001   110.   5.13e+3  6.14e+3
#  57    13    20 0.402     0.5   0.476     0.5    57468.   5.75e-4 -1.08e-2
#  58    13    15 0.00537   0.5   1         0.1    30670.  -7.77e-1 -3.33e+2
#  59    13    47 0.218     0.5   0.0466    0.05   17553.  -3.21e-5  1.72e-4
#  60    13    15 0.487     0.5   0.00979   0.01    5458.  -8.12e-4  3.02e-2
#  61    13    24 0.720     0.5   0.00482   0.005   3038.  -9.33e-5  5.28e-3
#  62    13    54 1         0.5   0.00109   0.001    851.  -3.08e-1 -2.10e-1
#  63    13    18 0.00001   0.5   0.0208    0.0005   459.   2.26e+3  1.13e-6
#  64    13    33 0.0000921 0.5   0.0000472 0.0001   109.  -2.15e+2  4.76e+3
#  65    12    20 0.425     0.5   0.489     0.5    58621.  -5.97e-3  2.77e-3
#  66    12    15 0.00611   0.5   1         0.1    30868.  -3.21e-3 -2.20e+2
#  67    12    39 0.00001   0.5   0.602     0.05   18625.   6.74e+3  5.26e-3
#  68    12    19 1         0.5   0.0104    0.01    5727.  -2.94e-3 -1.26e-4
#  69    12    18 0.436     0.5   0.00515   0.005   3211.  -2.18e-4 -3.34e-2
#  70    12    54 0.624     0.5   0.000932  0.001    741.  -3.42e-1 -2.01e+2
#  71    12    18 0.00001   0.5   0.0157    0.0005   359.   2.30e+3 -3.81e-2
#  72    12    34 0.00001   0.5   0.0000521 0.0001    91.8  5.75e+3  9.14e+3
#  73    11    22 0.480     0.5   0.507     0.5    59179.  -7.87e-4 -1.43e-2
#  74    11    16 0.00436   0.5   1         0.1    31240.   3.16e-2 -2.13e+2
#  75    11    22 0.00001   0.5   0.612     0.05   18855.   7.15e+3  6.09e-5
#  76    11    15 0.389     0.5   0.0102    0.01    5622.  -1.63e-4  7.25e-3
#  77    11    26 0.971     0.5   0.00479   0.005   3023.  -1.09e-4  4.64e-2
#  78    11    59 0.143     0.5   0.00122   0.001    938.  -1.30e-2 -1.31e+1
#  79    11    48 0.00001   0.5   0.000413  0.0005   520.   2.42e+4 -5.13e+0
#  80    11    59 0.00001   0.5   0.0000648 0.0001   119.   3.38e+2  6.39e+3
#  81    10    22 0.515     0.5   0.499     0.5    59422.  -3.19e-2 -2.71e-1
#  82    10    15 0.00667   0.5   1         0.1    30380.  -1.44e-2 -4.25e+2
#  83    10    25 0.00001   0.5   0.617     0.05   18957.   7.14e+3  1.81e-4
#  84    10    18 0.864     0.5   0.0101    0.01    5603.  -3.37e-4  1.72e-2
#  85    10    30 0.112     0.5   0.00452   0.005   2880.  -4.91e-3  1.77e-1
#  86    10    34 1         0.5   0.00116   0.001    898.  -1.03e-1 -5.85e-4
#  87    10    58 0.00001   0.5   0.000343  0.0005   422.   1.52e+4 -1.75e-2
#  88    10    36 0.0000138 0.5   0.000118  0.0001   102.  -1.83e+3 -2.66e+3
#  89     9    22 0.430     0.5   0.493     0.5    58722.   2.33e-5  6.58e-5
#  90     9    14 0.00428   0.5   1         0.1    29857.  -1.59e-1 -5.44e+2
#  91     9    41 0.000297  0.5   0.636     0.05   19204.  -5.88e+1  6.54e-1
#  92     9    22 0.454     0.5   0.0108    0.01    5910.  -2.17e-4 -1.34e-2
#  93     9    23 0.567     0.5   0.00530   0.005   3286.  -2.66e-4  1.52e-2
#  94     9    38 0.379     0.5   0.000984  0.001    775.  -3.91e-1 -5.67e+0
#  95     9    25 0.00001   0.5   0.00666   0.0005   450.   6.80e+3 -2.07e-2
#  96     9    15 0.00001   0.5   0.00551   0.0001   144.   2.24e+3  4.06e-4
#  97     8    22 0.417     0.5   0.488     0.5    58694.  -1.37e-2  1.03e-1
#  98     8    24 0.00391   0.5   1         0.1    30077.  -4.91e-1 -5.03e+2
#  99     8    24 0.00001   0.5   0.632     0.05   19302.   6.94e+3 -1.36e-4
# 100     8    12 0.212     0.5   0.00965   0.01    5397.  -9.41e-5  5.16e-3
# 101     8    31 0.565     0.5   0.00519   0.005   3230.  -1.20e-3 -2.18e+0
# 102     8    38 0.237     0.5   0.00100   0.001    788.  -2.73e-4 -3.39e-3
# 103     8    31 0.00001   0.5   0.00589   0.0005   404.   6.45e+3 -3.48e-1
# 104     8    52 0.00001   0.5   0.0000290 0.0001    91.9  1.07e+4  5.11e+3
# 105     7    21 0.427     0.5   0.486     0.5    58199.  -4.57e-3  3.36e-3
# 106     7    15 0.00412   0.5   1         0.1    30655.   1.71e-3 -7.17e+2
# 107     7    37 0.000288  0.5   0.651     0.05   19598.  -2.94e+2 -4.38e-1
# 108     7    17 0.789     0.5   0.0100    0.01    5553.  -1.51e-4  3.13e-2
# 109     7    36 0.225     0.5   0.00504   0.005   3151.   4.87e-4 -4.82e+0
# 110     7    29 0.471     0.5   0.000894  0.001    712.  -1.85e-5  1.28e-3
# 111     7    60 0.00001   0.5   0.000292  0.0005   391.   1.27e+4 -1.24e+2
# 112     7    28 0.00001   0.5   0.00550   0.0001   144.   2.11e+3 -1.88e-1
# 113     6    21 0.435     0.5   0.493     0.5    58874.  -7.69e-3  3.64e-2
# 114     6    13 0.00601   0.5   1         0.1    30506.  -5.84e-3 -4.94e+2
# 115     6    21 0.00001   0.5   0.359     0.05   18914.   1.17e+4 -4.76e-4
# 116     6    23 0.295     0.5   0.0104    0.01    5739.  -4.68e-3 -3.05e-1
# 117     6    16 1         0.5   0.00530   0.005   3293.  -6.18e-1 -1.19e-5
# 118     6    28 1         0.5   0.00111   0.001    865.  -2.16e-1  8.15e-6
# 119     6    17 0.00001   0.5   0.00589   0.0005   404.   6.68e+3 -1.63e-1
# 120     6    64 0.00001   0.5   0.0000556 0.0001   101.   3.85e+3  7.79e+3
# 121     5    21 0.446     0.5   0.492     0.5    57950.  -6.45e-3  2.92e-3
# 122     5    15 0.00680   0.5   1         0.1    31007.  -4.84e-2 -3.65e+2
# 123     5    24 0.00001   0.5   0.633     0.05   19311.   2.86e+3 -3.80e-4
# 124     5    12 0.271     0.5   0.00962   0.01    5381.   9.12e-6  3.05e-2
# 125     5    19 0.357     0.5   0.00470   0.005   2967.  -6.94e-4 -2.83e-1
# 126     5    40 0.207     0.5   0.000891  0.001    712.  -5.74e-2 -3.42e+2
# 127     5    15 0.00001   0.5   0.00602   0.0005   412.   6.80e+3 -6.50e-3
# 128     5    35 0.000461  0.5   0.0000941 0.0001    99.0  3.38e+2  9.33e+3
# 129     4    20 0.433     0.5   0.492     0.5    58339.  -1.10e-2  6.14e-3
# 130     4    14 0.00407   0.5   1         0.1    30106.   1.95e-2 -7.37e+2
# 131     4    40 0.000585  0.5   0.653     0.05   19495.  -1.42e+1  4.00e-1
# 132     4    12 0.365     0.5   0.00951   0.01    5322.  -1.83e-3 -2.01e-1
# 133     4    21 0.240     0.5   0.00466   0.005   2944.  -1.28e-4  4.02e-3
# 134     4    34 0.156     0.5   0.000973  0.001    768.  -1.79e-1 -7.26e+1
# 135     4    18 0.00001   0.5   0.00589   0.0005   404.   6.36e+3  3.93e-5
# 136     4    63 0.00001   0.5   0.0000690 0.0001   119.   4.88e+3  6.28e+3
# 137     3    23 0.411     0.5   0.486     0.5    58079.  -1.74e-5 -1.59e-4
# 138     3    16 0.00840   0.5   1         0.1    30036.   2.05e-3 -8.22e+1
# 139     3    68 0.000309  0.5   0.634     0.05   19224.  -8.08e+1  6.05e-1
# 140     3    27 1         0.5   0.0101    0.01    5613.  -2.82e-1 -1.20e+0
# 141     3    18 0.206     0.5   0.00528   0.005   3267.  -4.98e-4  8.26e-3
# 142     3    26 0.988     0.5   0.00106   0.001    830.  -1.42e-2 -1.63e+2
# 143     3    55 0.00001   0.5   0.000322  0.0005   422.   1.18e+4 -8.46e+1
# 144     3    31 0.00001   0.5   0.0000284 0.0001    92.1  1.17e+4  4.05e+3
# 145     2    23 0.511     0.5   0.504     0.5    59699.  -5.63e-2  7.62e-2
# 146     2    15 0.00506   0.5   1         0.1    31011.  -1.25e-2 -4.78e+2
# 147     2    21 0.000553  0.5   0.650     0.05   19466.  -3.74e-3 -3.54e-4
# 148     2    11 0.285     0.5   0.00979   0.01    5437.  -1.36e-3  3.13e-1
# 149     2    26 0.874     0.5   0.00506   0.005   3161.  -7.00e-6 -1.67e-2
# 150     2    34 0.333     0.5   0.00109   0.001    851.  -7.73e-3 -1.20e+1
# 151     2    56 0.00001   0.5   0.000265  0.0005   392.   2.71e+3 -1.38e+3
# 152     2    58 0.00001   0.5   0.000119  0.0001   101.   6.25e+2 -1.51e+3
# 153     1    22 0.450     0.5   0.502     0.5    58418.  -2.14e-2  2.79e-2
# 154     1    36 0.000892  0.5   0.756     0.1    31426.  -1.22e+0  6.06e-2
# 155     1    43 0.0000349 0.5   0.0194    0.05   19135.   1.75e+4 -2.11e+2
# 156     1    22 1         0.5   0.00999   0.01    5544.  -4.42e-2 -3.41e-1
# 157     1    21 0.337     0.5   0.00516   0.005   3214.  -7.36e-3  9.50e-1
# 158     1    50 0.170     0.5   0.00104   0.001    816.  -6.62e-3 -8.13e+0
# 159     1    13 0.00001   0.5   0.0130    0.0005   304.   2.35e+3 -1.75e-3
# 160     1    57 0.00001   0.5   0.0000272 0.0001    92.4  1.17e+4  2.70e+2
